# %%
import json
import turtle
import urllib.request
import time
import webbrowser
import geocoder

# %%
url = "http://api.open-notify.org/astros.json"
response = urllib.request.urlopen(url)
result = json.loads(response.read())
file = open("iss.txt", "w")
file.write("We currently have " + 
           str(result["number"]) + " astronauts on the ISS. \n\n")
people = result["people"]
for p in people:
    file.write(p['name'] + " - on board" + "\n")
#Print Long & Lat
g = geocoder.ip('me')

file.write("\n Your current lat/long is:" + str(g.latlng))
file.close()
webbrowser.open("iss.txt")
# Out:
# True

# %%
#set up world map
screen = turtle.Screen()
screen.setup(1280, 720)
screen.setworldcoordinates(-180,-90,180,90)

# %%
#loading map Image
screen.bgpic("map.gif")
screen.register_shape("iss.gif")
iss = turtle.Turtle()
iss.shape("iss.gif")
iss.setheading(45)
iss.penup()

# %%
while True:
    #load current status of the ISS in real time. 
    url = "http://api.open-notify.org/iss-now.json"
    response = urllib.request.urlopen(url)
    result = json.loads(response.read())

    #Extract coordinates
    location = result["iss_position"]
    lat = location['latitude']
    lon = location['longitude']

    #OutPut to the terminal
    lat = float(lat)
    lon = float(lon)

    print("\nLatitude: " + str(lat))
    print("\nLongitude: " + str(lon))

    #update position of the ISS
    iss.goto(lon, lat)

    #refresh every 2 seconds
    time.sleep(2)
# Out:
# Latitude: 4.3604
#
# Longitude: 61.7152
#
# Latitude: 4.5123
#
# Longitude: 61.8237
#
# Latitude: 4.6389
#
# Longitude: 61.9142
#
# Latitude: 4.7654
#
# Longitude: 62.0047
#
# Latitude: 4.8919
#
# Longitude: 62.0952
#
# Latitude: 5.0438
#
# Longitude: 62.204
#
# Latitude: 5.1703
#
# Longitude: 62.2946
#
# Latitude: 5.2968
#
# Longitude: 62.3853
#
# Latitude: 5.4232
#
# Longitude: 62.476
#
# Latitude: 5.575
#
# Longitude: 62.5849
#
# Latitude: 5.7014
#
# Longitude: 62.6758
#
# Latitude: 5.8279
#
# Longitude: 62.7666
#
# Latitude: 5.9543
#
# Longitude: 62.8575
#
# Latitude: 6.1059
#
# Longitude: 62.9667
#
# Latitude: 6.2323
#
# Longitude: 63.0577
#
# Latitude: 6.3586
#
# Longitude: 63.1488
#
# Latitude: 6.485
#
# Longitude: 63.2399
#
# Latitude: 6.6113
#
# Longitude: 63.3311
#
# Latitude: 6.7628
#
# Longitude: 63.4405
#
# Latitude: 6.8891
#
# Longitude: 63.5318
#
# Latitude: 7.0154
#
# Longitude: 63.6232
#
# Latitude: 7.1669
#
# Longitude: 63.7329
#
# Latitude: 7.293
#
# Longitude: 63.8243
#
# Latitude: 7.4192
#
# Longitude: 63.9158
#
# Latitude: 7.5454
#
# Longitude: 64.0074
#
# Latitude: 7.6968
#
# Longitude: 64.1174
#
# Latitude: 7.8229
#
# Longitude: 64.2092
#
# Latitude: 7.9489
#
# Longitude: 64.3009
#
# Latitude: 8.1002
#
# Longitude: 64.4112
#
# Latitude: 8.2262
#
# Longitude: 64.5031
#
# Latitude: 8.3522
#
# Longitude: 64.5951
#
# Latitude: 8.5034
#
# Longitude: 64.7055
#
# Latitude: 8.6293
#
# Longitude: 64.7977
#
# Latitude: 8.7553
#
# Longitude: 64.8899
#
# Latitude: 9.007
#
# Longitude: 65.0745
#
# Latitude: 9.1328
#
# Longitude: 65.1669
#
# Latitude: 9.2586
#
# Longitude: 65.2594
#
# Latitude: 9.3844
#
# Longitude: 65.352
#
# Latitude: 9.5102
#
# Longitude: 65.4446
#
# Latitude: 9.661
#
# Longitude: 65.5559
#
# Latitude: 9.7867
#
# Longitude: 65.6487
#
# Latitude: 9.9123
#
# Longitude: 65.7416
#
# Latitude: 10.0631
#
# Longitude: 65.8531
#
# Latitude: 10.1887
#
# Longitude: 65.9462
#
# Latitude: 10.3142
#
# Longitude: 66.0394
#
# Latitude: 10.4397
#
# Longitude: 66.1326
#
# Latitude: 10.5903
#
# Longitude: 66.2445
#
# Latitude: 10.7157
#
# Longitude: 66.338
#
# Latitude: 10.8411
#
# Longitude: 66.4315
#
# Latitude: 10.9664
#
# Longitude: 66.525
#
# Latitude: 11.1168
#
# Longitude: 66.6374
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ADMIN\Documents\Projects\CodeProjects\res\ISS-Tracker-main\ISS-Tracker-main\tracker.ipynb Cell 5 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/ADMIN/Documents/Projects/CodeProjects/res/ISS-Tracker-main/ISS-Tracker-main/tracker.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a> iss.goto(lon, lat)
#      <a href='vscode-notebook-cell:/c%3A/Users/ADMIN/Documents/Projects/CodeProjects/res/ISS-Tracker-main/ISS-Tracker-main/tracker.ipynb#W5sZmlsZQ%3D%3D?line=21'>22</a> #refresh every 2 seconds
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ADMIN/Documents/Projects/CodeProjects/res/ISS-Tracker-main/ISS-Tracker-main/tracker.ipynb#W5sZmlsZQ%3D%3D?line=22'>23</a> time.sleep(2)
#
# KeyboardInterrupt:
